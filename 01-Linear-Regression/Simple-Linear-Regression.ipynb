# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('placement.csv')

# %%
df.head(10)
# Out:
#    cgpa  package
# 0  2.76     3.26
# 1  2.05     1.98
# 2  3.13     3.25
# 3  2.97     3.67
# 4  2.78     3.57
# 5  3.16     2.99
# 6  2.69     2.60
# 7  2.70     2.48
# 8  2.44     2.31
# 9  3.32     3.51

# %%
df.nunique()
# Out:
# cgpa       115
# package    138
# dtype: int64

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package in lakhs')
# Out:
# Text(0, 0.5, 'Package in lakhs')

# %%
X=df.iloc[:,0:1]
Y=df.iloc[:,-1]

# %%
X
# Out:
#      cgpa
# 0    2.76
# 1    2.05
# 2    3.13
# 3    2.97
# 4    2.78
# ..    ...
# 195  2.77
# 196  2.36
# 197  2.88
# 198  3.05
# 199  2.49
#
# [200 rows x 1 columns]

# %%
Y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test= train_test_split(X,Y, test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      cgpa
# 112  3.43
# 29   2.86
# 182  2.35
# 199  2.49
# 193  1.83
# 85   1.92
# 10   2.13
# 54   2.74
# 115  3.34
# 35   2.75
# 12   3.58
# 92   3.16
# 13   2.77
# 126  2.36
# 174  2.93
# 2    3.13
# 44   2.04
# 3    2.97
# 113  2.78
# 14   3.09
# 23   2.48
# 25   2.91
# 6    2.69
# 134  2.88
# 165  3.28
# 173  2.70
# 45   3.15
# 65   3.04
# 48   3.45
# 122  2.05
# 178  3.26
# 64   2.94
# 9    3.32
# 57   2.64
# 78   2.64
# 71   2.99
# 128  3.17
# 176  2.52
# 131  2.55
# 53   2.59

# %%
Y_test
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# 85     1.48
# 10     1.86
# 54     3.09
# 115    4.21
# 35     2.87
# 12     3.65
# 92     4.00
# 13     2.89
# 126    2.60
# 174    2.99
# 2      3.25
# 44     1.86
# 3      3.67
# 113    2.37
# 14     3.42
# 23     2.48
# 25     3.65
# 6      2.60
# 134    2.83
# 165    4.08
# 173    2.56
# 45     3.58
# 65     3.81
# 48     4.09
# 122    2.01
# 178    3.63
# 64     2.92
# 9      3.51
# 57     1.94
# 78     2.21
# 71     3.34
# 128    3.34
# 176    3.23
# 131    2.01
# 53     2.61
# Name: package, dtype: float64

# %%
# Now check the test data if model is predicting it right
lr.predict(X_test.iloc[[0]])
# Out:
# array([3.88930803])

# %%
# Best fit line
# slope of line and y-intercept
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package in lakhs')
# Out:
# Text(0, 0.5, 'Package in lakhs')

# %%
# Slope   (m)
m=lr.coef_
m
# Out:
# array([1.39634583])

# %%
# intercept   (b)
b=lr.intercept_
b
# Out:
# np.float64(-0.9001581587214722)

# %%
# y = mx + b
m * 2.86 + b
# Out:
# array([3.0933909])
