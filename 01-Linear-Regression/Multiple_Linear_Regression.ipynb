# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression

# %%
X,y=make_regression(n_samples=100, n_features=2, n_targets=1, n_informative=2, noise=)

# %%
df= pd.DataFrame({'feature1':X[:,0],'feature2' : X[:,1], 'target':y})

# %%
df.head(10)
# Out:
#    feature1  feature2      target
# 0 -2.290909  0.077795 -101.941028
# 1  1.590380  0.764078   91.519683
# 2 -0.629520 -0.070637  -45.832342
# 3 -0.409572 -1.415080  -46.473552
# 4 -1.124990 -0.128182  -62.582447
# 5  1.307921  0.407422   70.882114
# 6 -0.301879  0.826776   16.465692
# 7 -0.153556  1.159630   32.484729
# 8  0.928637  1.272952   62.099885
# 9  0.118208  1.319915   36.705126

# %%
df.shape
# Out:
# (100, 3)

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')
fig.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.2, random_state=3)

# %%
X_test
# Out:
# array([[-0.79193091,  0.83709757],
#        [-0.90450137, -2.05597355],
#        [-0.30187929,  0.82677568],
#        [-0.12213762,  0.29932157],
#        [-0.18762331,  2.12624414],
#        [-1.61998149, -0.99135832],
#        [ 2.0813871 ,  0.62206669],
#        [ 0.46313484,  0.24288704],
#        [-0.84864011,  0.76091552],
#        [-2.08131037, -1.11169411],
#        [ 0.07847769, -1.15699658],
#        [ 0.1182081 ,  1.31991495],
#        [-2.31954649, -2.62543636],
#        [ 0.99512937,  1.24408248],
#        [-0.30776809, -1.24385074],
#        [-0.0867404 ,  1.80178607],
#        [-0.76540961, -0.08238892],
#        [-0.3552817 , -0.56063217],
#        [ 0.25356487, -0.77446213],
#        [ 0.56132587, -0.19762626]])

# %%
y_test
# Out:
# array([  -7.5803247 , -101.60471257,   16.46569202,   -2.85113004,
#          50.64296485,  -98.83726445,  112.76081876,   49.39260285,
#         -10.37263943, -122.18008812,  -27.28191431,   36.70512614,
#        -173.64629211,   93.4240629 ,  -31.95179817,   37.25951763,
#         -39.91748345,  -11.61368441,    3.4441403 ,   13.15361783])

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test[[0]])
# Out:
# array([-12.36713222])

# %%
lr.coef_
# Out:
# array([ 8.28950962, 62.81628427])

# %%
lr.intercept_
# Out:
# np.float64(0.22174483995209213)
