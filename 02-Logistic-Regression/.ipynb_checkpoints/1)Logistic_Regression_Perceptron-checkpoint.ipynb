# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("perceptron_logistic_dataset.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('perceptron_logistic_dataset.csv')
plt.figure(figsize=(10,6))
plt.scatter(df['Feature_1'], df['Feature_2'], c=df['Target'], cmap='winter', s=100)
plt.title('Linearly Separable Dataset')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.savefig('classification_graph.png')
print("File generated at: classification_graph.png")
# Out:
# File generated at: classification_graph.png

# %%
df.head()
# Out:
#    Feature_1  Feature_2  Target
# 0   0.199247  -0.116976       1
# 1  -0.248820  -0.731152       1
# 2  -0.354490  -0.708106       1
# 3  -1.590865  -2.011992       0
# 4  -0.200840   1.634932       1

# %%
X=df.iloc[:,0:2]
X
# Out:
#     Feature_1  Feature_2
# 0    0.199247  -0.116976
# 1   -0.248820  -0.731152
# 2   -0.354490  -0.708106
# 3   -1.590865  -2.011992
# 4   -0.200840   1.634932
# ..        ...        ...
# 95  -2.123327   0.661988
# 96  -1.535998   0.071533
# 97  -1.460347   0.323236
# 98   0.836266  -0.345742
# 99  -0.265706   0.064999
#
# [100 rows x 2 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0     1
# 1     1
# 2     1
# 3     0
# 4     1
#      ..
# 95    0
# 96    0
# 97    0
# 98    1
# 99    1
# Name: Target, Length: 100, dtype: int64

# %%
def perceptron(X,y):
    X=np.insert(X,0,1, axis=1)
    weight=np.ones(X.shape[1])
    learning_rate=1

    for i in range(1000):
        j=np.random.randint(0,100)
        y_hat= step(np.dot(X[j],weight))
        weight= weight + learning_rate*(y[j]-y_hat)* X[j]
    return weight[0], weight[1:]

# %%
# Step function
def step(z):
    return 1 if z>0 else 0

# %%
intercept, coef= perceptron(X,y)

# %%
intercept
# Out:
# np.float64(1.0)

# %%
coef
# Out:
# array([1.56334253, 0.07946109])
